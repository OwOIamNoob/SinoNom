# %%
import numpy as np
import json
import matplotlib.pyplot as plt

# %%
file = open("/work/hpc/potato/SinoNom/data/wb_recognition_dataset/manifest.json", "r")
labels = json.load(file)

# %%
len(labels.keys())
# Out:
# 2130

# %%
length = [len(value) for value in labels.values()]
length
# Out:
# [285,
#  220,
#  195,
#  141,
#  134,
#  130,
#  128,
#  122,
#  120,
#  109,
#  108,
#  106,
#  105,
#  102,
#  101,
#  100,
#  97,
#  95,
#  92,
#  91,
#  89,
#  88,
#  88,
#  86,
#  83,
#  83,
#  82,
#  82,
#  82,
#  81,
#  79,
#  79,
#  78,
#  78,
#  76,
#  76,
#  76,
#  75,
#  74,
#  74,
#  73,
#  72,
#  71,
#  70,
#  69,
#  69,
#  68,
#  68,
#  67,
#  66,
#  66,
#  66,
#  65,
#  64,
#  64,
#  63,
#  63,
#  62,
#  62,
#  61,
#  61,
#  61,
#  61,
#  60,
#  60,
#  60,
#  60,
#  59,
#  59,
#  59,
#  59,
#  58,
#  58,
#  58,
#  58,
#  58,
#  57,
#  57,
#  57,
#  57,
#  56,
#  56,
#  55,
#  55,
#  55,
#  54,
#  54,
#  54,
#  54,
#  54,
#  53,
#  53,
#  53,
#  53,
#  53,
#  53,
#  53,
#  53,
#  52,
#  52,
#  52,
#  52,
#  51,
#  51,
#  51,
#  51,
#  50,
#  50,
#  50,
#  50,
#  50,
#  50,
#  49,
#  49,
#  49,
#  49,
#  48,
#  48,
#  48,
#  48,
#  48,
#  48,
#  48,
#  48,
#  48,
#  48,
#  48,
#  47,
#  47,
#  47,
#  46,
#  46,
#  46,
#  46,
#  46,
#  46,
#  46,
#  46,
#  45,
#  45,
# ...

# %%
plt.fill_between(range(len(length)), y1=length)

# %%
mean = np.median(length)
mean
# Out:
# 28.0

# %%
domain plot
